# %% [markdown]
# <a href="https://colab.research.google.com/github/KaushalKumar-100/Machine_learning_hacthon/blob/main/model_testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle

# %%
with open("reinforcement.pkl", "rb") as f:
    Q_loaded = pickle.load(f)

type(Q_loaded)
# Out:
# dict

# %%
len(Q_loaded)
# Out:
# 6

# %%
list(Q_loaded.items())[:10]
# Out:
# [((1, 0), array([3815.82465877, 7207.2912548 , 4992.4077683 ])),
#  ((0, 0), array([2403.08673704, 2994.02460818, 2819.83184398])),
#  ((-1, 0), array([4558.52285121, 7411.78647488, 3518.09267685])),
#  ((1, 1), array([11044.51174006, 10341.93218879,  8650.59514873])),
#  ((-1, 1), array([10623.01462561,  9921.619662  , 10131.81058443])),
#  ((0, 1), array([4640.53062764, 4497.44829642, 3703.56168666]))]

# %%
import numpy as np

state = (1, 0)  # price going UP, not holding stock

action = np.argmax(Q_loaded[state])
print("Action:", action)
# Out:
# Action: 1

# %%
state=(-1,0)
action=np.argmax(Q_loaded[state])
print("action",action)
# Out:
# action 1

# %%
state=(-1,1)
action=np.argmax(Q_loaded[state])
print("action",action)
# Out:
# action 0
